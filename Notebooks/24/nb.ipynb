# %%
C:\Users\Lisara\Downloads\Task 2 - Document Collection Visual Question Answering (DocCVQA)\sample_public_v02.json

# %%
import numpy as np

# %%
path_f = r"C:\Users\Lisara\Downloads\Task 2 - Document Collection Visual Question Answering (DocCVQA)\spdocvqa_imdb\imdb_test.npy"
data = np.load(path_f, allow_pickle=True)

# %%
data
# Out:
# array([{'creation_time': 1637837044.756368, 'version': 1.0, 'dataset_type': 'test', 'has_answer': False},
# ...
